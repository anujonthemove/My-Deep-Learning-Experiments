# %%
# Program to calculate moving average using numpy

import numpy as np

# %%
def loop_moving_average(arr = [1, 2, 3, 7, 9], window_size = 3):
    i = 0
    # Initialize an empty list to store moving averages
    moving_averages = []

    # Loop through the array t o
    #consider every window of size 3
    while i < len(arr) - window_size + 1:

        # Calculate the average of current window
        window_average = round(np.sum(arr[
        i:i+window_size]) / window_size, 2)

        # Store the average of current
        # window in moving average list
        moving_averages.append(window_average)

        # Shift window to right by one position
        i += 1

    # print(moving_averages)
    return moving_averages

# %%
arr = np.random.randint(0, 1000000, 100000)

# %%
moving_averages = loop_moving_average(arr, window_size=3)

# %%
moving_averages
# Out:
# [650769.0,
#  682816.33,
#  478623.0,
#  463598.33,
#  497387.67,
#  568757.33,
#  599155.0,
#  492714.33,
#  547697.67,
#  308958.67,
#  516464.33,
#  311541.33,
#  467633.0,
#  317440.33,
#  574290.33,
#  408118.33,
#  637326.33,
#  480428.0,
#  708468.0,
#  515318.67,
#  492154.67,
#  292033.0,
#  406735.33,
#  437507.0,
#  374434.33,
#  185738.0,
#  301719.67,
#  359395.0,
#  541789.67,
#  359618.67,
#  546602.33,
#  374886.33,
#  553950.0,
#  503397.33,
#  507265.67,
#  371691.0,
#  378901.67,
#  489425.67,
#  572637.67,
#  558140.0,
#  712052.33,
#  621092.0,
#  506711.33,
#  513806.67,
#  550548.67,
#  735030.67,
#  546787.67,
#  577541.33,
#  517943.67,
#  634611.33,
#  681049.0,
#  644179.67,
#  668175.33,
#  573864.0,
#  539063.0,
#  440337.67,
#  634689.67,
#  652421.33,
#  701415.33,
#  381724.67,
#  368830.0,
#  383747.33,
#  472623.33,
#  374889.0,
#  150847.0,
#  366915.0,
#  323880.33,
#  469090.67,
#  338976.0,
#  358092.33,
#  311955.33,
#  449718.0,
#  517757.0,
# ...

# %%
def moving_average(x, w):
    return np.convolve(x, np.ones(w), 'valid') / w

# %%
# x = np.array([5,3,8,10,2,1,5,1,0,2])
# x = np.array(arr)

# %%
# moving_average(x, 3)

# %%
moving_average(arr, w=3)
# Out:
# array([650769.        , 682816.33333333, 478623.        , ...,
#        597256.        , 503335.        , 404460.66666667])

# %% [markdown]
# # References
#
# 1. https://stackoverflow.com/questions/14313510/how-to-calculate-rolling-moving-average-using-python-numpy-scipy
# 2. https://www.delftstack.com/howto/python/moving-average-python/
# 3. https://www.geeksforgeeks.org/how-to-calculate-moving-averages-in-python/#:~:text=1%3A%20Using%20Numpy-,Numpy%20module%20of%20Python%20provides%20an%20easy%20way%20to%20calculate,elements%20of%20the%20given%20array.
